# %% [markdown]
# ## Importar librerias y leer .env

# %%
import os

from dotenv import load_dotenv
from pyspark.sql import SparkSession

load_dotenv()

S3_BUCKET = os.getenv("S3_BUCKET")

print("Bucket:", S3_BUCKET)
# Out:
# Bucket: football-data-lake-22030108

# %% [markdown]
# ### Configurar sesion de Spark

# %%
spark = (
    SparkSession.builder
    .appName("Football Data Lake - API Football")
    .getOrCreate()
)

print("Spark Version:", spark.version)
# Out:
# Spark Version: 3.5.8
# 26/05/11 13:46:15 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %% [markdown]
# ### Visualizar que archivos hay en s3

# %%
print(
    spark.sparkContext.getConf().get("spark.jars.packages")
)
# Out:
# None

# %%
print(spark.version)
# Out:
# 3.5.8

# %%
spark.sparkContext._jsc.hadoopConfiguration().get("fs.defaultFS")
# Out:
# 'hdfs://localhost:9000'
